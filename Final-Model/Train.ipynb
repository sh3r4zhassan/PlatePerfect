# %%
# !pip install ultralytics
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install onnxruntime
import onnxruntime as ort
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.8/645.8 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 59.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.5 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO
import cv2
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/gdrive')
print(os.listdir())
os.chdir('gdrive/My Drive/Ubicomp/Final')
# Out:
# Mounted at /content/gdrive
# ['.config', 'gdrive', 'sample_data']

# %%
# model = YOLO('yolov8n-seg.pt')

# Using a pretrained model

model_path = '/content/gdrive/My Drive/Ubicomp/Final/runs/segment/train2/weights/last.pt'
model = YOLO(model_path)

# %%
model.train(data='config.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.218 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
model_path = '/content/gdrive/My Drive/Ubicomp/Final/runs/segment/train3/weights/best.pt'
model = YOLO(model_path)

# %%
model.export(format="onnx")
# Out:
# Ultralytics YOLOv8.0.218 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-seg summary (fused): 195 layers, 3594049 parameters, 0 gradients, 13.5 GFLOPs
#
# PyTorch: starting from '/content/gdrive/My Drive/Ubicomp/Final/runs/segment/train3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 139, 8400), (1, 32, 160, 160)) (7.1 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 0.9s, saved as '/content/gdrive/My Drive/Ubicomp/Final/runs/segment/train3/weights/best.onnx' (13.9 MB)
#
# Export complete (2.4s)
# Results saved to /content/gdrive/My Drive/Ubicomp/Final/runs/segment/train3/weights
# Predict:         yolo predict task=segment model=/content/gdrive/My Drive/Ubicomp/Final/runs/segment/train3/weights/best.onnx imgsz=640
# Validate:        yolo val task=segment model=/content/gdrive/My Drive/Ubicomp/Final/runs/segment/train3/weights/best.onnx imgsz=640 data=config.yaml
# ...
